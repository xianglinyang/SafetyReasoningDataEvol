# %%
path = "/home/ljiahao/xianglin/git_space/DarkCite/outputs/attack/llama-3-SCoT/1753639658_wxalut1o/data.jsonl"

import json
all_data = []

with open(path, "r") as f:
    for line in f:
        data = json.loads(line)
        all_data.append(data)

# %%
questions = [data["goal"] for data in all_data]
targets = [data["target_str"] for data in all_data]

# %%
from src.evaluate.evaluate_harmful import HarmbenchClassifierVLLM
classifier = HarmbenchClassifierVLLM(device="cuda", tensor_parallel_size=1)

responses = classifier.batch_moderate(questions, targets)
# Out:
# 2025-07-31 16:09:58.653406: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753949398.666584 3061894 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753949398.670388 3061894 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1753949398.681803 3061894 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
unsafe_scores=classifier.batch_get_unsafe_score(responses)
sum(unsafe_scores[:500])/500, sum(unsafe_scores[500:1000])/500, sum(unsafe_scores[1000:1500])/500
# Out:
# (0.006, 0.004, 0.002)
